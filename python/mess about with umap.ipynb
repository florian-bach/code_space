# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline
import os
import pylab
import numpy as np

# %%
sns.set(style='white', context='poster', rc={'figure.figsize':(14,10)})

# %%
os.chdir('/Users/s1249052/Downloads/experiment_177051_illustration_234393_spill_applied_fcs_files/Output')
os.getcwd()

flow_data = pd.read_csv("one.csv",sep=',')

# %%
cytobank=flow_data[['141Pr_CD196_CCR6',
 '142Nd_CD19',
 '143Nd_CD127_IL-7Ra',
 '144Nd_CD38',
 '146Nd_IgD',
 '147Sm_CD11c',
 '148Nd_CD16',
 '149Sm_CD194_CCR4',
 '151Eu_CD123_IL-3R',
 '152Sm_TCRgd',
 '153Eu_CD185_CXCR5',
 '154Sm_CD3',
 '155Gd_CD45RA',
 '158Gd_CD27',
 '160Gd_CD28',
 '162Dy_CD66b',
 '163Dy_CD183_CXCR3',
 '164Dy_CD161',
 '165Ho_CD45RO',
 '166Er_CD24',
 '167Er_CD197_CCR7',
 '168Er_CD8',
 '169Tm_CD25_IL-2Ra',
 '171Yb_CD20',
 '173Yb_HLADR',
 '174Yb_CD4',
 '175Lu_CD14',
 '176Yb_CD56_NCAM']].copy()

# %%
trans=cytobank.apply(np.arcsinh, 'columns')
trans.head(20)
len(trans.columns)
# Out:
# 28

# %%
def draw_umap(n_neighbors=40, min_dist=0.1, n_components=2, metric='euclidean', title=''):
    fit = umap.UMAP(
        n_neighbors=n_neighbors,
        min_dist=min_dist,
        n_components=n_components,
        metric=metric
    )
    u = fit.fit_transform(trans);
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.scatter(u[:,0], u[:,1], c=trans['174Yb_CD4'])
    
    plt.title(title, fontsize=18)

# %%
for d in (0.0, 0.1, 0.25, 0.5, 0.99):
    draw_umap(min_dist=d, title='min_dist = {}'.format(d))
